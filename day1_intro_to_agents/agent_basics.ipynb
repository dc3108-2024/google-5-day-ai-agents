# %% [markdown]
# # Day 1 – Intro to Agents
#
# **TODO:** Import today's Kaggle notebook once published.
#
# ## Instructions
#
# 1. Complete the notebook on Kaggle
# 2. Download: File → Download `.ipynb`
# 3. Replace this file with the downloaded notebook
# 4. Update `notes.md` with key takeaways

# %%
# Optional: Quick smoke test for Google AI Studio .. test change
# Uncomment to verify your API key is configured correctly

# import os
# import google.generativeai as genai
#
# genai.configure(api_key=os.environ.get("GOOGLE_API_KEY", ""))
# print("Ready. Attach GOOGLE_API_KEY as Kaggle Secret before running.")
